# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
DF_GDP = pd.read_csv("GDP_by_Country.csv", sep = ",", skiprows= range(0,4))

# %%
DF_GDP.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code          1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  5.377778e+08
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD           NaN
#
#            1961          1962          1963          1964          1965  ...  \
# 0           NaN           NaN           NaN           NaN           NaN  ...
# 1  5.488889e+08  5.466667e+08  7.511112e+08  8.000000e+08  1.006667e+09  ...
# 2           NaN           NaN           NaN           NaN           NaN  ...
# 3           NaN           NaN           NaN           NaN           NaN  ...
# 4           NaN           NaN           NaN           NaN           NaN  ...
#
# ...

# %%
del DF_GDP['Unnamed: 62']
del DF_GDP['2017']

# %%
DF_GDPT = DF_GDP.T
DF_GDPT.head()
# Out:
#                               0                  1                  2    \
# Country Name                Aruba        Afghanistan             Angola
# Country Code                  ABW                AFG                AGO
# Indicator Name  GDP (current US$)  GDP (current US$)  GDP (current US$)
# Indicator Code     NY.GDP.MKTP.CD     NY.GDP.MKTP.CD     NY.GDP.MKTP.CD
# 1960                          NaN        5.37778e+08                NaN
#
#                               3                  4                  5    \
# Country Name              Albania            Andorra         Arab World
# Country Code                  ALB                AND                ARB
# Indicator Name  GDP (current US$)  GDP (current US$)  GDP (current US$)
# Indicator Code     NY.GDP.MKTP.CD     NY.GDP.MKTP.CD     NY.GDP.MKTP.CD
# 1960                          NaN                NaN                NaN
#
#                                  6                  7                  8    \
# ...

# %%
DF_GDPT.columns = DF_GDPT.iloc[0]
DF_GDPT.head()
# Out:
# Country Name                Aruba        Afghanistan             Angola  \
# Country Name                Aruba        Afghanistan             Angola
# Country Code                  ABW                AFG                AGO
# Indicator Name  GDP (current US$)  GDP (current US$)  GDP (current US$)
# Indicator Code     NY.GDP.MKTP.CD     NY.GDP.MKTP.CD     NY.GDP.MKTP.CD
# 1960                          NaN        5.37778e+08                NaN
#
# Country Name              Albania            Andorra         Arab World  \
# Country Name              Albania            Andorra         Arab World
# Country Code                  ALB                AND                ARB
# Indicator Name  GDP (current US$)  GDP (current US$)  GDP (current US$)
# Indicator Code     NY.GDP.MKTP.CD     NY.GDP.MKTP.CD     NY.GDP.MKTP.CD
# 1960                          NaN                NaN                NaN
#
# Country Name    United Arab Emirates          Argentina            Armenia  \
# ...

# %%
def Country_GDP(Country):
    Country_name = DF_GDPT[Country]
    Country_GDP = Country_name[4:]
    return Country_GDP

# %%
def Graph_GDP(country1, country2, country3):
    plt.xlabel('Year', fontsize = 18) 
    plt.ylabel('GDP Growth', fontsize = 18) 
    plt.title('GDP Growth', fontsize=18) 
    plt.style.use('seaborn-whitegrid')
    
    Country_GDP(country1).plot(legend = 'Upper left', color ='red', label= country1, figsize=(8,6))
    Country_GDP(country2).plot(legend = 'Upper left', color = 'blue', label = country2)
    Country_GDP(country3).plot(legend = 'Upper left', color = 'black', label = country3)
    plt.legend(loc=2, prop={'size': 15})
    plt.tick_params(axis = 'both', which = 'major', labelsize = 14, length = 10.0)

# %%
DF_Inf = pd.read_csv("MortalityFertilityIncome.csv", sep = ",")

# %%
DF_Inf.head()
# Out:
#   Country Name Country Code                     Region  m1970 m1971 m1972  \
# 0        Aruba          ABW  Latin America & Caribbean    NaN   NaN   NaN
# 1  Afghanistan          AFG                 South Asia  204,8   201   197
# 2       Angola          AGO         Sub-Saharan Africa    NaN   NaN   NaN
# 3      Albania          ALB      Europe & Central Asia    NaN   NaN   NaN
# 4      Andorra          AND      Europe & Central Asia    NaN   NaN   NaN
#
#    m1973  m1974  m1975  m1976  ...        i2007        i2008        i2009  \
# 0    NaN    NaN    NaN    NaN  ...          NaN          NaN          NaN
# 1  193,1  188,8  184,7  180,6  ...  331,3254993  331,2271678  395,5679021
# 2    NaN    NaN    NaN    NaN  ...  629,2704433   251,732843  902,6093382
# 3    NaN    NaN    NaN    NaN  ...  3343,591615  3961,319155  3622,890286
# 4    NaN    NaN    NaN    NaN  ...          NaN          NaN          NaN
#
#          i2010        i2011        i2012        i2013        i2014  \
# ...

# %%
DF_MFIT = DF_Inf.T
DF_MFIT.head()
# Out:
#                                     0            1                   2    \
# Country Name                      Aruba  Afghanistan              Angola
# Country Code                        ABW          AFG                 AGO
# Region        Latin America & Caribbean   South Asia  Sub-Saharan Africa
# m1970                               NaN        204,8                 NaN
# m1971                               NaN          201                 NaN
#
#                                 3                      4    \
# Country Name                Albania                Andorra
# Country Code                    ALB                    AND
# Region        Europe & Central Asia  Europe & Central Asia
# m1970                           NaN                    NaN
# m1971                           NaN                    NaN
#
#                                      5                          6    \
# Country Name        United Arab Emirates                  Argentina
# ...

# %%
DF_MFIT.columns = DF_MFIT.iloc[0]
DF_MFIT.head()
# Out:
# Country Name                      Aruba  Afghanistan              Angola  \
# Country Name                      Aruba  Afghanistan              Angola
# Country Code                        ABW          AFG                 AGO
# Region        Latin America & Caribbean   South Asia  Sub-Saharan Africa
# m1970                               NaN        204,8                 NaN
# m1971                               NaN          201                 NaN
#
# Country Name                Albania                Andorra  \
# Country Name                Albania                Andorra
# Country Code                    ALB                    AND
# Region        Europe & Central Asia  Europe & Central Asia
# m1970                           NaN                    NaN
# m1971                           NaN                    NaN
#
# Country Name        United Arab Emirates                  Argentina  \
# Country Name        United Arab Emirates                  Argentina
# ...

# %%
Dot_DF_MFIT = DF_MFIT.stack().str.replace(',','.').unstack()
Dot_DF_MFIT.head()
# Out:
# Country Name                      Aruba  Afghanistan              Angola  \
# Country Name                      Aruba  Afghanistan              Angola
# Country Code                        ABW          AFG                 AGO
# Region        Latin America & Caribbean   South Asia  Sub-Saharan Africa
# m1970                               NaN        204.8                 NaN
# m1971                               NaN          201                 NaN
#
# Country Name                Albania                Andorra  \
# Country Name                Albania                Andorra
# Country Code                    ALB                    AND
# Region        Europe & Central Asia  Europe & Central Asia
# m1970                           NaN                    NaN
# m1971                           NaN                    NaN
#
# Country Name        United Arab Emirates                  Argentina  \
# Country Name        United Arab Emirates                  Argentina
# ...

# %%
Mortality = Dot_DF_MFIT['Spain'][3:50]

# %%
Fertality = Dot_DF_MFIT['Spain'][50:97]

# %%
Income = Dot_DF_MFIT['Spain'][97:]

# %%
def Country_Mortality(Country):
    Country_name = Dot_DF_MFIT[Country][3:50]
    return Country_name.astype(float)

def Country_Fertility(Country):
    Country_name = Dot_DF_MFIT[Country][50:97]
    return Country_name.astype(float)

def Country_Income(Country):
    Country_name = Dot_DF_MFIT[Country][97:]
    return Country_name.astype(float)

# %%
def Graph_Mortality(country1, country2, country3): 
    plt.xlabel('Year', fontsize = 18) 
    plt.ylabel('Mortality rate (Per 1,000 live births)', fontsize = 18) 

    plt.title('Mortality Rate of '+ country1 + ", " + country2 + " and " + country3 , fontsize=18) 
    plt.style.use('seaborn-whitegrid')
    
    Country_Mortality(country1).plot(legend = 'Upper right', color ='red', label= country1, figsize=(8,6))
    Country_Mortality(country2).plot(legend = 'Upper right', color = 'blue', label = country2)
    Country_Mortality(country3).plot(legend = 'Upper right', color = 'black', label = country3)
    plt.legend(loc=1, prop={'size': 15})
    plt.tick_params(axis = 'both', which = 'major', labelsize = 14, length = 10)

# %%
def Graph_Fertility(country1, country2, country3): 
    plt.xlabel('Year', fontsize = 18) 
    plt.ylabel('Total (births per woman)', fontsize = 18) 
  
    plt.title('Fertility Rate of '+ country1 + ", " + country2 + " and " + country3 , fontsize=18) 
    plt.style.use('seaborn-whitegrid')
    
    Country_Fertility(country1).plot(legend = 'Upper right', color ='red', label= country1, figsize=(8,6))
    Country_Fertility(country2).plot(legend = 'Upper right', color = 'blue', label = country2)
    Country_Fertility(country3).plot(legend = 'Upper right', color = 'black', label = country3)
    plt.legend(loc=1, prop={'size': 15})
    plt.tick_params(axis = 'both', which = 'major', labelsize = 14, length = 10)

# %%
def Graph_Income(country1, country2, country3): 
    plt.xlabel('Year', fontsize = 18) 
    plt.ylabel('US $', fontsize = 18) 
  
    plt.title('Adjusted net national income per capita of '+ country1 + ", " + country2 + " and " + country3 , fontsize=14) 
    plt.style.use('seaborn-whitegrid')
    
    Country_Income(country1).plot(legend = 'Upper right', color ='red', label= country1, figsize=(8,6))
    Country_Income(country2).plot(legend = 'Upper right', color = 'blue', label = country2)
    Country_Income(country3).plot(legend = 'Upper right', color = 'black', label = country3)
    plt.legend(loc=2, prop={'size': 15})
    plt.tick_params(axis = 'both', which = 'major', labelsize = 14, length = 10)

# %%
DF_Pop = pd.read_csv("PopulationPerCountry.csv", sep = ",", skiprows = range(0,4))
del DF_Pop['Unnamed: 62']
del DF_Pop['2017']
DF_Pop.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996351.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5643182.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965  ...        2007  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    101220.0
# 1  9166764.0  9345868.0  9533954.0  9731361.0  9938414.0  ...  26616792.0
# 2  5753024.0  5866061.0  5980417.0  6093321.0  6203299.0  ...  20997687.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2970017.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0  ...     82683.0
#
#          2008        2009        2010        2011        2012        2013  \
# ...

# %%
DF_PopT = DF_Pop.transpose()
DF_PopT.columns = DF_PopT.iloc[0]
DF_PopT.head()
# Out:
# Country Name                Aruba        Afghanistan             Angola  \
# Country Name                Aruba        Afghanistan             Angola
# Country Code                  ABW                AFG                AGO
# Indicator Name  Population, total  Population, total  Population, total
# Indicator Code        SP.POP.TOTL        SP.POP.TOTL        SP.POP.TOTL
# 1960                        54211        8.99635e+06        5.64318e+06
#
# Country Name              Albania            Andorra         Arab World  \
# Country Name              Albania            Andorra         Arab World
# Country Code                  ALB                AND                ARB
# Indicator Name  Population, total  Population, total  Population, total
# Indicator Code        SP.POP.TOTL        SP.POP.TOTL        SP.POP.TOTL
# 1960                   1.6088e+06              13411        9.24909e+07
#
# Country Name    United Arab Emirates          Argentina            Armenia  \
# ...

# %%
DF_PopT = DF_PopT[4:].astype(float)

# %%
def Graph_Pop(country1, country2, country3): 
    plt.xlabel('Year', fontsize = 18) 
    plt.ylabel('Population in Millions', fontsize = 18) 
  
    plt.title('Population of '+ country1 + ", " + country2 + " and " + country3 , fontsize=14) 
    plt.style.use('seaborn-whitegrid')
    
    DF_PopT[country1].plot(legend = 'Upper right', color ='red', label= country1, figsize=(10,6))
    DF_PopT[country2].plot(legend = 'Upper right', color = 'blue', label = country2)
    DF_PopT[country3].plot(legend = 'Upper right', color = 'black', label = country3)
    plt.legend(loc=2, prop={'size': 15})
    plt.tick_params(axis = 'both', which = 'major', labelsize = 14, length = 10)

# %%
DF_Agri = pd.read_csv("AgriculturalMachinery_PerUnitofArableLand.csv", sep = ",", skiprows = range(0,4))

# %%
del DF_Agri['2009']
del DF_Agri['2010']
del DF_Agri['2011']
del DF_Agri['2012']
del DF_Agri['2013']
del DF_Agri['2014']
del DF_Agri['2015']
del DF_Agri['2016']
del DF_Agri['2017']
del DF_Agri['Unnamed: 62']

# %%
DF_Agri.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS   NaN
# 1  Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS   NaN
# 2  Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS   NaN
# 3  Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS   NaN
# 4  Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS   NaN
#
#         1961       1962       1963       1964       1965  ...        1999  \
# 0        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 1   0.156863   0.194805   0.258065   0.256410   0.384615  ...    0.143734
# 2   2.996255   6.092593   7.352941  10.243636  10.830325  ...         NaN
# ...

# %%
DF_AgriT = DF_Agri.transpose()

# %%
DF_AgriT.columns = DF_AgriT.iloc[0]

# %%
DF_AgriT.head()
# Out:
# Country Name                                                Aruba  \
# Country Name                                                Aruba
# Country Code                                                  ABW
# Indicator Name  Agricultural machinery, tractors per 100 sq. k...
# Indicator Code                                     AG.LND.TRAC.ZS
# 1960                                                          NaN
#
# Country Name                                          Afghanistan  \
# Country Name                                          Afghanistan
# Country Code                                                  AFG
# Indicator Name  Agricultural machinery, tractors per 100 sq. k...
# Indicator Code                                     AG.LND.TRAC.ZS
# 1960                                                          NaN
#
# Country Name                                               Angola  \
# Country Name                                               Angola
# ...

# %%
def Graph_Agri(country1, country2, country3): 
    plt.xlabel('Year', fontsize = 18) 
    plt.ylabel('# of Agricultural Machines', fontsize = 18) 
  
    # giving a title to my graph 
    plt.title('Agricultural Machines per hectare of land '+ country1 + ", " + country2 + " and " + country3 , fontsize=14) 
    plt.style.use('seaborn-whitegrid')
    
    DF_AgriT[country1][4:].plot(legend = 'Upper right', color ='red', label= country1, figsize=(10,6))
    DF_AgriT[country2][4:].plot(legend = 'Upper right', color = 'blue', label = country2)
    DF_AgriT[country3][4:].plot(legend = 'Upper right', color = 'black', label = country3)
    plt.legend(loc=2, prop={'size': 15})
    plt.tick_params(axis = 'both', which = 'major', labelsize = 14, length = 10)

# %%
DF_Terror = pd.read_csv("globalterrorismdb_0718dist.csv", sep = ',', low_memory=False)

# %%
DF_Terror.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
DF_Terror_merger = DF_Terror[['iyear','country_txt']].copy()
DF_Terror_merger.head()
# Out:
#    iyear         country_txt
# 0   1970  Dominican Republic
# 1   1970              Mexico
# 2   1970         Philippines
# 3   1970              Greece
# 4   1970               Japan

# %%
Yearly_Terror = DF_Terror_merger.groupby(['country_txt','iyear']).size().reset_index(name='count')
Yearly_Terror.head()
# Out:
#    country_txt  iyear  count
# 0  Afghanistan   1973      1
# 1  Afghanistan   1979      3
# 2  Afghanistan   1987      1
# 3  Afghanistan   1988     11
# 4  Afghanistan   1989     10

# %%
Yearly_TerrorT = Yearly_Terror.transpose()
Yearly_TerrorT
# Out:
#                     0            1            2            3            4     \
# country_txt  Afghanistan  Afghanistan  Afghanistan  Afghanistan  Afghanistan
# iyear               1973         1979         1987         1988         1989
# count                  1            3            1           11           10
#
#                     5            6            7            8            9     \
# country_txt  Afghanistan  Afghanistan  Afghanistan  Afghanistan  Afghanistan
# iyear               1990         1991         1992         1994         1995
# count                  2           30           36            9            6
#
#              ...      3752      3753      3754      3755      3756      3757  \
# country_txt  ...  Zimbabwe  Zimbabwe  Zimbabwe  Zimbabwe  Zimbabwe  Zimbabwe
# iyear        ...      2002      2003      2006      2007      2008      2010
# count        ...         8         1         1         1         5         1
#
# ...

# %%
Yearly_TerrorT.columns = Yearly_TerrorT.iloc[0]
Yearly_TerrorT['Afghanistan']
# Out:
# country_txt  Afghanistan  Afghanistan  Afghanistan  Afghanistan  Afghanistan  \
# country_txt  Afghanistan  Afghanistan  Afghanistan  Afghanistan  Afghanistan
# iyear               1973         1979         1987         1988         1989
# count                  1            3            1           11           10
#
# country_txt  Afghanistan  Afghanistan  Afghanistan  Afghanistan  Afghanistan  \
# country_txt  Afghanistan  Afghanistan  Afghanistan  Afghanistan  Afghanistan
# iyear               1990         1991         1992         1994         1995
# count                  2           30           36            9            6
#
# country_txt  ...  Afghanistan  Afghanistan  Afghanistan  Afghanistan  \
# country_txt  ...  Afghanistan  Afghanistan  Afghanistan  Afghanistan
# iyear        ...         2008         2009         2010         2011
# count        ...          414          503          542          421
#
# ...

# %%
def Plotting_Terror(Country1, Country2, Country3):
    x = Yearly_TerrorT[Country1].iloc[[1]]
    y = Yearly_TerrorT[Country1].iloc[[2]]
    x1 = Yearly_TerrorT[Country2].iloc[[1]]
    y1 = Yearly_TerrorT[Country2].iloc[[2]]
    x2 = Yearly_TerrorT[Country3].iloc[[1]]
    y2 = Yearly_TerrorT[Country3].iloc[[2]]    
    plt.figure(figsize=(10,8))
    plt.xlabel('Year', fontsize = 18) 
    plt.ylabel('# of Terroristic Incidents', fontsize = 18) 
    
    plt.title('Terror Incidents for '+ Country1 + ", " + Country2 + " and " + Country3 , fontsize=14) 
    plt.style.use('seaborn-whitegrid')
    
    
    plt.tick_params(axis = 'both', which = 'major', labelsize = 14, length = 10)
      
    CA = plt.scatter(x,y, label = Country1, marker ='x', color='r')
    CB = plt.scatter(x1,y1, label=Country2, marker = 'x', color = 'b')
    CC = plt.scatter(x2,y2, marker = 'x', label = Country3, color='g')
    
    plt.legend((CA, CB, CC), (Country1, Country2, Country3), loc='upper left',fontsize=14)
    plt.xticks(np.arange(1970,2017,6))

# %% [markdown]
# Master DF - Ground Work Above

# %%
Terror_Incidents= DF_Terror.groupby(['country_txt']).size().reset_index(name='T_Incidents')
Terror_Incidents.head()
# Out:
#    country_txt  T_Incidents
# 0  Afghanistan        12731
# 1      Albania           80
# 2      Algeria         2743
# 3      Andorra            1
# 4       Angola          499

# %%
Terror_Incidents = Terror_Incidents.rename(columns={'country_txt': 'Country Name'})

# %%
DF_GDP.columns = ["g" + str(col) for col in DF_GDP]

# %%
DF_GDP = DF_GDP.rename(columns={'gCountry Name': 'Country Name', 'gCountry Code':'Country Code'})
DF_GDP.head()
# Out:
#   Country Name Country Code    gIndicator Name gIndicator Code         g1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  5.377778e+08
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD           NaN
#
#           g1961         g1962         g1963         g1964         g1965  ...  \
# 0           NaN           NaN           NaN           NaN           NaN  ...
# 1  5.488889e+08  5.466667e+08  7.511112e+08  8.000000e+08  1.006667e+09  ...
# 2           NaN           NaN           NaN           NaN           NaN  ...
# 3           NaN           NaN           NaN           NaN           NaN  ...
# 4           NaN           NaN           NaN           NaN           NaN  ...
#
# ...

# %%
DF_Pop.columns = ['p' + str(col) for col in DF_Pop]

# %%
DF_Pop = DF_Pop.rename(columns={'pCountry Name': 'Country Name', 'pCountry Code':'Country Code'})
DF_Pop.head()
# Out:
#   Country Name Country Code    pIndicator Name pIndicator Code      p1960  \
# 0        Aruba          ABW  Population, total     SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total     SP.POP.TOTL  8996351.0
# 2       Angola          AGO  Population, total     SP.POP.TOTL  5643182.0
# 3      Albania          ALB  Population, total     SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total     SP.POP.TOTL    13411.0
#
#        p1961      p1962      p1963      p1964      p1965  ...       p2007  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    101220.0
# 1  9166764.0  9345868.0  9533954.0  9731361.0  9938414.0  ...  26616792.0
# 2  5753024.0  5866061.0  5980417.0  6093321.0  6203299.0  ...  20997687.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2970017.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0  ...     82683.0
#
# ...

# %%
DF_Agri.columns = ['a' + str(col) for col in DF_Agri]

# %%
DF_Agri = DF_Agri.rename(columns={'aCountry Name': 'Country Name', 'aCountry Code':'Country Code'})
DF_Agri.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                      aIndicator Name aIndicator Code  a1960  \
# 0  Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS    NaN
# 1  Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS    NaN
# 2  Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS    NaN
# 3  Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS    NaN
# 4  Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS    NaN
#
#        a1961      a1962      a1963      a1964      a1965  ...       a1999  \
# 0        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 1   0.156863   0.194805   0.258065   0.256410   0.384615  ...    0.143734
# 2   2.996255   6.092593   7.352941  10.243636  10.830325  ...         NaN
# ...

# %%
DF_dot_Inf = DF_Inf.stack().str.replace(',','.').unstack()
DF_dot_Inf.head()
# Out:
#   Country Name Country Code                     Region  m1970 m1971 m1972  \
# 0        Aruba          ABW  Latin America & Caribbean    NaN   NaN   NaN
# 1  Afghanistan          AFG                 South Asia  204.8   201   197
# 2       Angola          AGO         Sub-Saharan Africa    NaN   NaN   NaN
# 3      Albania          ALB      Europe & Central Asia    NaN   NaN   NaN
# 4      Andorra          AND      Europe & Central Asia    NaN   NaN   NaN
#
#    m1973  m1974  m1975  m1976  ...        i2007        i2008        i2009  \
# 0    NaN    NaN    NaN    NaN  ...          NaN          NaN          NaN
# 1  193.1  188.8  184.7  180.6  ...  331.3254993  331.2271678  395.5679021
# 2    NaN    NaN    NaN    NaN  ...  629.2704433   251.732843  902.6093382
# 3    NaN    NaN    NaN    NaN  ...  3343.591615  3961.319155  3622.890286
# 4    NaN    NaN    NaN    NaN  ...          NaN          NaN          NaN
#
#          i2010        i2011        i2012        i2013        i2014  \
# ...

# %%
DF_Inf_Terror = Terror_Incidents.merge(DF_dot_Inf, 'outer')
Ter_Inf_GDP_DF = DF_Inf_Terror.merge(DF_GDP, 'outer')
Ter_Inf_GDP_Agr_DF = Ter_Inf_GDP_DF.merge(DF_Agri, 'outer')
Master_DF = Ter_Inf_GDP_Agr_DF.merge(DF_Pop, 'outer')

# %%
Master_DF = Master_DF.rename(columns={'Country Name': ''})
Master_DF.head()
# Out:
#                 T_Incidents Country Code                      Region  m1970  \
# 0  Afghanistan      12731.0          AFG                  South Asia  204.8
# 1      Albania         80.0          ALB       Europe & Central Asia    NaN
# 2      Algeria       2743.0          DZA  Middle East & North Africa  145.6
# 3      Andorra          1.0          AND       Europe & Central Asia    NaN
# 4       Angola        499.0          AGO          Sub-Saharan Africa    NaN
#
#    m1971  m1972  m1973  m1974  m1975  ...       p2007       p2008       p2009  \
# 0    201    197  193.1  188.8  184.7  ...  26616792.0  27294031.0  28004331.0
# 1    NaN    NaN    NaN    NaN    NaN  ...   2970017.0   2947314.0   2927519.0
# 2  143.2  140.2  136.6  132.5  128.1  ...  34300076.0  34860715.0  35465760.0
# 3    NaN    NaN    NaN    NaN    NaN  ...     82683.0     83861.0     84462.0
# 4    NaN    NaN    NaN    NaN    NaN  ...  20997687.0  21759420.0  22549547.0
#
# ...

# %%
Master_DFT = Master_DF.transpose()

Master_DFT.head()
# Out:
#                       0                      1                           2    \
#               Afghanistan                Albania                     Algeria
# T_Incidents         12731                     80                        2743
# Country Code          AFG                    ALB                         DZA
# Region         South Asia  Europe & Central Asia  Middle East & North Africa
# m1970               204.8                    NaN                       145.6
#
#                                 3                   4    \
#                             Andorra              Angola
# T_Incidents                       1                 499
# Country Code                    AND                 AGO
# Region        Europe & Central Asia  Sub-Saharan Africa
# m1970                           NaN                 NaN
#
#                                     5                          6    \
#                     Antigua and Barbuda                  Argentina
# ...

# %%
Master_DFT.columns = Master_DFT.iloc[0]
Master_DFT.head()
# Out:
#               Afghanistan                Albania                     Algeria  \
#               Afghanistan                Albania                     Algeria
# T_Incidents         12731                     80                        2743
# Country Code          AFG                    ALB                         DZA
# Region         South Asia  Europe & Central Asia  Middle East & North Africa
# m1970               204.8                    NaN                       145.6
#
#                             Andorra              Angola  \
#                             Andorra              Angola
# T_Incidents                       1                 499
# Country Code                    AND                 AGO
# Region        Europe & Central Asia  Sub-Saharan Africa
# m1970                           NaN                 NaN
#
#                     Antigua and Barbuda                  Argentina  \
#                     Antigua and Barbuda                  Argentina
# ...

# %%
Master_DFT.columns.values
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia',
#        'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan',
#        'Bolivia', 'Bosnia-Herzegovina', 'Botswana', 'Brazil', 'Brunei',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Costa Rica', 'Croatia', 'Cuba', 'Cyprus',
#        'Czech Republic', 'Czechoslovakia',
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
#        'Dominica', 'Dominican Republic', 'East Germany (GDR)',
#        'East Timor', 'Ecuador', 'Egypt', 'El Salvador',
#        'Equatorial Guinea', 'Eritrea', 'Estonia', 'Ethiopia',
#        'Falkland Islands', 'Fiji', 'Finland', 'France', 'French Guiana',
# ...

# %%
for row in Master_DFT.index:
    print(row, end = " ")
# Out:
#  T_Incidents Country Code Region m1970 m1971 m1972 m1973 m1974 m1975 m1976 m1977 m1978 m1979 m1980 m1981 m1982 m1983 m1984 m1985 m1986 m1987 m1988 m1989 m1990 m1991 m1992 m1993 m1994 m1995 m1996 m1997 m1998 m1999 m2000 m2001 m2002 m2003 m2004 m2005 m2006 m2007 m2008 m2009 m2010 m2011 m2012 m2013 m2014 m2015 m2016 f1970 f1971 f1972 f1973 f1974 f1975 f1976 f1977 f1978 f1979 f1980 f1981 f1982 f1983 f1984 f1985 f1986 f1987 f1988 f1989 f1990 f1991 f1992 f1993 f1994 f1995 f1996 f1997 f1998 f1999 f2000 f2001 f2002 f2003 f2004 f2005 f2006 f2007 f2008 f2009 f2010 f2011 f2012 f2013 f2014 f2015 f2016 i1970 i1971 i1972 i1973 i1974 i1975 i1976 i1977 i1978 i1979 i1980 i1981 i1982 i1983 i1984 i1985 i1986 i1987 i1988 i1989 i1990 i1991 i1992 i1993 i1994 i1995 i1996 i1997 i1998 i1999 i2000 i2001 i2002 i2003 i2004 i2005 i2006 i2007 i2008 i2009 i2010 i2011 i2012 i2013 i2014 i2015 i2016 gIndicator Name gIndicator Code g1960 g1961 g1962 g1963 g1964 g1965 g1966 g1967 g1968 g1969 g1970 g1971 g1972 g1973 g19
# ...

# %%
#Example 1
Master_DFT[['Poland','Brazil','Canada']].loc[['m2015','f2015','T_Incidents','i2015','g2015']]
# Out:
#                  Poland       Brazil       Canada
# m2015               4.2           14          4.5
# f2015              1.32         1.74          1.6
# T_Incidents          39          273           96
# i2015        10659.6554   7439.69522  35294.48904
# g2015        4.7728e+11  1.80365e+12  1.55281e+12

# %%
#Example 2
Master_DFT.loc['g1990':'g2016',['Poland', 'Brazil','Canada']]
# Out:
#             Poland       Brazil       Canada
# g1990  6.59777e+10  4.61952e+11   5.9393e+11
# g1991  8.55009e+10   6.0286e+11  6.10328e+11
# g1992  9.43371e+10  4.00599e+11  5.92388e+11
# g1993  9.60456e+10  4.37799e+11  5.77171e+11
# g1994  1.10803e+11  5.58112e+11  5.78139e+11
# g1995  1.42137e+11  7.85643e+11  6.04032e+11
# g1996  1.59943e+11  8.50426e+11  6.28546e+11
# g1997  1.59118e+11  8.83199e+11  6.52825e+11
# g1998  1.74388e+11  8.63723e+11  6.31813e+11
# g1999  1.69718e+11  5.99389e+11  6.76083e+11
# g2000  1.71886e+11  6.55421e+11  7.42293e+11
# g2001  1.90521e+11  5.59373e+11   7.3638e+11
# g2002  1.98681e+11  5.07963e+11  7.57951e+11
# g2003  2.17519e+11   5.5832e+11  8.92381e+11
# g2004  2.55102e+11  6.69316e+11   1.0232e+12
# g2005  3.06135e+11   8.9163e+11  1.16936e+12
# g2006  3.44826e+11  1.10764e+12  1.31542e+12
# g2007   4.2925e+11  1.39708e+12  1.46498e+12
# g2008  5.33816e+11  1.69582e+12  1.54913e+12
# g2009  4.40347e+11  1.66702e+12  1.37115e+12
# ...

# %%
def Graph_GDP(country1, country2, country3):
    plt.xlabel('Year', fontsize = 18) 
    plt.ylabel('USD', fontsize = 18) 
  
    plt.title('GDP Growth of '+ country1 + " "+ country2 + " "+country3, fontsize=18) 
    plt.style.use('seaborn-whitegrid')
    
    Master_DFT.loc['g1960':'g2016',country1].plot(legend = 'Upper left', color ='red', label= country1, figsize=(8,6))
    Master_DFT.loc['g1960':'g2016',country2].plot(legend = 'Upper left', color = 'blue', label = country2)
    Master_DFT.loc['g1960':'g2016',country3].plot(legend = 'Upper left', color = 'black', label = country3)
    plt.legend(loc=2, prop={'size': 15})
    plt.tick_params(axis = 'both', which = 'major', labelsize = 14, length = 10.0)

# %%
def Graph_Income(country1, country2, country3): 
    plt.xlabel('Year', fontsize = 18) 
    plt.ylabel('US $', fontsize = 18) 
  
    plt.title('Adjusted net national income per capita of '+ country1 + ", " + country2 + " and " + country3 , fontsize=14) 
    plt.style.use('seaborn-whitegrid')
    
    C1 = Master_DFT.loc['i1970':'i2016',country1].astype(float)
    C2 = Master_DFT.loc['i1970':'i2016',country2].astype(float)
    C3 = Master_DFT.loc['i1970':'i2016',country3].astype(float)
    
    C1.plot(legend = 'Upper right', color ='red', label= country1, figsize=(8,6))
    C2.plot(legend = 'Upper right', color = 'blue', label = country2)
    C3.plot(legend = 'Upper right', color = 'black', label = country3)
    plt.legend(loc=2, prop={'size': 15})
    plt.tick_params(axis = 'both', which = 'major', labelsize = 14, length = 10)

# %%
def Graph_Mortality(country1, country2, country3): 
    plt.xlabel('Year', fontsize = 18) 
    plt.ylabel('Mortality rate (Per 1,000 live births)', fontsize = 18) 
  
    plt.title('Mortality Rate of '+ country1 + ", " + country2 + " and " + country3 , fontsize=18) 
    plt.style.use('seaborn-whitegrid')
    
    C1 = Master_DFT.loc['m1970':'m2016',country1].astype(float)
    C2 = Master_DFT.loc['m1970':'m2016',country2].astype(float)
    C3 = Master_DFT.loc['m1970':'m2016',country3].astype(float)
    
    C1.plot(legend = 'Upper right', color ='red', label= country1, figsize=(8,6))
    C2.plot(legend = 'Upper right', color = 'blue', label = country2)
    C3.plot(legend = 'Upper right', color = 'black', label = country3)
    plt.legend(loc=1, prop={'size': 15})
    plt.tick_params(axis = 'both', which = 'major', labelsize = 14, length = 10)

# %%
def Graph_Fertility(country1, country2, country3): 
    plt.xlabel('Year', fontsize = 18) 
    plt.ylabel('Total (births per woman)', fontsize = 18) 

    plt.title('Fertility Rate of '+ country1 + ", " + country2 + " and " + country3 , fontsize=18) 
    plt.style.use('seaborn-whitegrid')
    
    C1 = Master_DFT.loc['f1970':'f2016',country1].astype(float)
    C2 = Master_DFT.loc['f1970':'f2016',country2].astype(float)
    C3 = Master_DFT.loc['f1970':'f2016',country3].astype(float)
    
    C1.plot(legend = 'Upper right', color ='red', label= country1, figsize=(8,6))
    C2.plot(legend = 'Upper right', color = 'blue', label = country2)
    C3.plot(legend = 'Upper right', color = 'black', label = country3)
    plt.legend(loc=1, prop={'size': 15})
    plt.tick_params(axis = 'both', which = 'major', labelsize = 14, length = 10)

# %%
def Graph_Pop(country1, country2, country3): 
    plt.xlabel('Year', fontsize = 18) 
    plt.ylabel('Population in Millions', fontsize = 18) 
  
    plt.title('Population of '+ country1 + ", " + country2 + " and " + country3 , fontsize=14) 
    plt.style.use('seaborn-whitegrid')
    
    Master_DFT.loc['p1960':'p2016',country1].plot(legend = 'Upper right', color ='red', label= country1, figsize=(10,6))
    Master_DFT.loc['p1960':'p2016',country2].plot(legend = 'Upper right', color = 'blue', label = country2)
    Master_DFT.loc['p1960':'p2016',country3].plot(legend = 'Upper right', color = 'black', label = country3)
    plt.legend(loc=2, prop={'size': 15})
    plt.tick_params(axis = 'both', which = 'major', labelsize = 14, length = 10)

# %%
def Graph_Agri(country1, country2, country3): 
    plt.xlabel('Year', fontsize = 18) 
    plt.ylabel('# of Agricultural Machines', fontsize = 18) 
  
    plt.title('Agricultural Machines per hectare of land '+ country1 + ", " + country2 + " and " + country3 , fontsize=14) 
    plt.style.use('seaborn-whitegrid')
    
    Master_DFT.loc['a1960':'a2008',country1].plot(legend = 'Upper right', color ='red', label= country1, figsize=(10,6))
    Master_DFT.loc['a1960':'a2008',country2].plot(legend = 'Upper right', color = 'blue', label = country2)
    Master_DFT.loc['a1960':'a2008',country3].plot(legend = 'Upper right', color = 'black', label = country3)
    plt.legend(loc=2, prop={'size': 15})
    plt.tick_params(axis = 'both', which = 'major', labelsize = 14, length = 10)

# %%
Graph_GDP('Poland','Brazil','Canada')

# %%
Graph_Income('Poland','Brazil','Canada')

# %%
Graph_Fertility('Poland','Brazil','Canada')

# %%
Graph_Mortality('Poland','Brazil','Canada')

# %%
Graph_Pop('Poland','Brazil','Canada')

# %%
Graph_Agri('Poland','Brazil','Canada')

# %%
Plotting_Terror('Poland', 'Brazil', 'Canada')

# %% [markdown]
# Sources:
#     https://stackoverflow.com/questions/2051744/reverse-y-axis-in-pyplot -Reverse axis
#     https://stackoverflow.com/questions/332289/how-do-you-change-the-size-of-figures-drawn-with-matplotlib -size of graph
#     https://stackoverflow.com/questions/31494870/pandas-dataframe-no-numeric-data-to-plot-error -Converting to float
#     https://stackoverflow.com/questions/40083266/replace-comma-with-dot-pandas -Converting commas to periods
#     https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.tick_params.html?highlight=tick_params#matplotlib.axes.Axes.tick_params -Graph x and y tick sizes
#     https://stackoverflow.com/questions/17411940/matplotlib-scatter-plot-legend -Scatter plot legend
#     https://stackoverflow.com/questions/39778686/pandas-reset-index-after-groupby-value-counts - Count colum
#     https://stackoverflow.com/questions/42940507/merging-dataframes-keeping-all-items-pandas - Merging outer
